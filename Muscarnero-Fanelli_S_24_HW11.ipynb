# %% [markdown]
# # PyObject:  Object-oriented programming HW 11

# %% [markdown]
# ## Exercise 1  (from Monday's class)

# %% [markdown]
# 1. Write a ``Particle`` class that can be used to represent a particle with a mass, a 3-d position, and a 3-d velocity.
#
# 2. Write a method that can be used to compute the kinetic energy of the particle
#
# 3. Write a method that takes another particle as an argument and finds the distance between the two particles
#
# 4. Write a method that given a time interval ``dt`` will update the position of the particle to the new position based on the current position and velocity.
#
# 5. Write a ``ChargedParticle`` class that inherits from the ``Particle`` class, but also has an attribute for the charge of the particle.

# %%
import numpy as np

#class ChargedParticle(Particle):

#    def __init__(self, mass, x, y, z, vx, vy, vz, charge):
#        self.mass = mass
#        self.x = x
#        self.y = y
#        self.z = z
#        self.vx = vx
#        self.vy = vy
#        self.vz = vz
#        self.charge = charge

# your solution here


# your solution here

class Particle(object): 
    def __init__(self, m, r_x, r_y, r_z, v_x, v_y, v_z):
        self.m = m
        self.rx = r_x
        self.ry = r_y
        self.rz = r_z
        self.vx = v_x
        self.vy = v_y
        self.vz = v_z
        
    def KinErg(self): 
        v = (((self.vx)**2)+((self.vy)**2)+((self.vz)**2))**(1/2)
        return (1/2)*self.m*(v**2)
    
    def dist(self, other): 
        return np.sqrt((other.rx - self.rx)**2 + (other.ry - self.ry)**2 + (other.rz - other.rz)**2)

    def move(self, dt):
        self.rx = self.rx + self.vx*dt
        self.ry = self.ry + self.vy*dt
        self.rz = self.rz + self.vz*dt
        
#class times(Particle): 
#    def dt(t_1, t_2): 
#        delta_t = self.t_2-self.t_1
#        return delta_t

class ChargedParticle(Particle): 
    def __init__(self, m, r_x, r_y, r_z, v_x, v_y, v_z, charge):
        self.m = m
        self.rx = r_x
        self.ry = r_y
        self.rz = r_z
        self.vx = v_x
        self.vy = v_y
        self.vz = v_z
        self.charge = charge

p1 = Particle(10,1,1,1,2,2,2)
p1.KinErg() #Yields correct numerical output

p2 = Particle(10,2,2,2,2,2,2)
p1.dist(p2) #Correct output

cp1 = ChargedParticle(10,1,1,1,2,2,2,10)
cp2 = ChargedParticle(10,2,2,2,2,2,2,10)

print(p1.rx)
p1.move(1)
print(p1.rx)
p1.dist(p2)
p1.KinErg()
cp1.charge()
# Out:
# 1
# 3
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [23], in <cell line: 72>()
#      70 p1.dist(p2)
#      71 p1.KinErg()
# ---> 72 cp1.charge()
#
# TypeError: 'int' object is not callable

# %% [markdown]
# ## Exercise 2  (New)

# %% [markdown]
# 6. Write a method that can be used to see if a particle is in the same place (e.g., find_seperation < 0.25).  If there are two ChargedParticles in the same place make a "simple" (*not correct physics*) "interaction". (__have the code print "interaction"__).
#
#     a. If the charges are opposite, make them "combine", set both velocities to zero and set their charge to zero, and print "merge".
#
#     b. Else, make the particles "repel", to do:
#
#         multiply each "self" velocity and  by (-1 * (self.charge+other.charge) * (self.mass/other.mass))
#
#         multiply each "other" velocity by (-1 * (self.charge+other.charge) * (other.mass/self.mass))
#
#     e.g., reversing it's velocity, and print "repel". __(Again this is bad physics, but we are focusing on coding so play along.)__
#
#
# 7. To test the above, write a code with two particles starting:
#
#         P1 at (x,y,z) = (-5,-5,-5) with (vx,vy,vz) = (1,1,1) and (charge = 0.5)
#
#         P2 at (x,y,z) = (5,5,5) with (vx,vy,vz) = (-1,-1,-1) and (charge = -0.5).
#
#     Use your dt time interval to move the particles in 0.05 time steps for 300 steps, and print the current poition and velocity of each particle at each time step.
#
#
# 8. To test the above, write a code with two particles starting:
#
#         P1 at (x,y,z) = (-5,-5,-5) with (vx,vy,vz) = (2,2,2) and (charge = 0.5)
#
#         P2 at (x,y,z) = (5,5,5) with (vx,vy,vz) = (-1,-1,-1) and (charge = 2.0).
#
#     Use your dt time interval to move the particles in 0.05 time steps for 300 steps, and print the current poition and velocity of each particle at each time step.

# %%
# write new code here
# write/copy code here
class Particle(object): 
    def __init__(self, m, r_x, r_y, r_z, v_x, v_y, v_z):
        self.m = m
        self.rx = r_x
        self.ry = r_y
        self.rz = r_z
        self.vx = v_x
        self.vy = v_y
        self.vz = v_z
        
    def KinErg(self): 
        v = (((self.vx)**2)+((self.vy)**2)+((self.vz)**2))**(1/2)
        return (1/2)*self.m*(v**2)
    
    def dist(self, other): 
        return np.sqrt((other.rx - self.rx)**2 + (other.ry - self.ry)**2 + (other.rz - other.rz)**2)

    def move(self, dt):
        self.rx = self.rx + self.vx*dt
        self.ry = self.ry + self.vy*dt
        self.rz = self.rz + self.vz*dt

class ChargedParticle(Particle): 
    def __init__(self, m, r_x, r_y, r_z, v_x, v_y, v_z, charge):
        self.m = m
        self.rx = r_x
        self.ry = r_y
        self.rz = r_z
        self.vx = v_x
        self.vy = v_y
        self.vz = v_z
        self.charge = charge

p1 = Particle(10,1,1,1,2,2,2)
p1.KinErg() #Yields correct numerical output

p2 = Particle(10,2,2,2,2,2,2)
p1.dist(p2) #Correct output

cp1 = ChargedParticle(10,1,1,1,2,2,2,10)
cp2 = ChargedParticle(10,2,2,2,2,2,2,10)
cp1.charge #Cannot use parentheses in the code after "cp1.charge" because it's defined as an integer
# Out:
# 10

# %%
p1 = Particle(10,1,1,1,2,2,2)
p2 = Particle(10,1.1,1.1,1.1,2,2,2)

cp1 = ChargedParticle(10,1,1,1,2,2,2,10)
cp2 = ChargedParticle(10,1.1,1.1,1.1,2,2,2,-10)

if p1.dist(p2) < 0.25: 
    print("Particles 1 and 2 are in the same place")

else: 
    print("Particles 1 and 2 are not in the same place")

if cp1.dist(cp2) < 0.25: 
    print("Interaction")
    if cp1.charge/cp2.charge < 0: 
        cp1.v= 0
        cp2.v= 0
        cp1.charge= 0
        cp2.charge= 0
        print("Merge")
    
    else: 
        print("Repel- Charges have the same sign")
    
else: 
    cp1.v = (-1*(cp1.charge+cp2.charge)*(cp1.m/cp2.m)) #Cannot use 'self' and 'other'; must use 'cp1' and 'cp2'
    cp2.v = (-1*(cp1.charge+cp2.charge)*(cp2.m/cp1.m))
    print("Repel- Particles do not get close enough")
    
#Tested code- works correctly
# Out:
# Particles 1 and 2 are in the same place
# Interaction
# Merge

# %%
#Test for number 7
#NOTE: Instructions do not specify a mass, so both masses are set to 1.
cp1 = ChargedParticle(1,-5,-5,-5, 1, 1, 1, 0.5)
cp2 = ChargedParticle(1, 5, 5, 5,-1,-1,-1,-0.5)

for i in range(1,300): 
    cp1.move(0.05)
    cp2.move(0.05)
    
    if cp1.dist(cp2) < 0.25: 
        print("Interaction")
        if cp1.charge/cp2.charge < 0: 
            cp1.v= 0
            cp2.v= 0
            cp1.charge= 0
            cp2.charge= 0
            print("Merge")
            
            break

        else: 
            print("Repel- Charges have the same sign")

    else: 
        cp1.v = (-1*(cp1.charge+cp2.charge)*(cp1.m/cp2.m)) #Cannot use 'self' and 'other'; must use 'cp1' and 'cp2'
        cp2.v = (-1*(cp1.charge+cp2.charge)*(cp2.m/cp1.m))
        print("Particles are not close enough")
    
    print("c1 position:", cp1.rx, cp1.ry, cp1.rz, cp1.vx, cp1.vy, cp1.vz)
    print("c2 position:", cp2.rx, cp2.ry, cp2.rz, cp2.vx, cp2.vy, cp2.vz)
# Out:
# Particles are not close enough
# c1 position: -4.95 -4.95 -4.95 1 1 1
# c2 position: 4.95 4.95 4.95 -1 -1 -1
# Particles are not close enough
# c1 position: -4.9 -4.9 -4.9 1 1 1
# c2 position: 4.9 4.9 4.9 -1 -1 -1
# Particles are not close enough
# c1 position: -4.8500000000000005 -4.8500000000000005 -4.8500000000000005 1 1 1
# c2 position: 4.8500000000000005 4.8500000000000005 4.8500000000000005 -1 -1 -1
# Particles are not close enough
# c1 position: -4.800000000000001 -4.800000000000001 -4.800000000000001 1 1 1
# c2 position: 4.800000000000001 4.800000000000001 4.800000000000001 -1 -1 -1
# Particles are not close enough
# c1 position: -4.750000000000001 -4.750000000000001 -4.750000000000001 1 1 1
# c2 position: 4.750000000000001 4.750000000000001 4.750000000000001 -1 -1 -1
# Particles are not close enough
# c1 position: -4.700000000000001 -4.700000000000001 -4.700000000000001 1 1 1
# c2 position: 4.700000000000001 4.700000000000001 4.700000000000001 -1 -1 -1
# ...

# %%
#Test for number 8
#NOTE: Instructions do not specify a mass, so both masses are set to 1.
cp1 = ChargedParticle(1,-5,-5,-5, 2, 2, 2, 0.5)
cp2 = ChargedParticle(1, 5, 5, 5,-1,-1,-1, 2.0)

for i in range(1,300): 
    cp1.move(0.05)
    cp2.move(0.05)
    
    if cp1.dist(cp2) < 0.25: 
        print("Interaction")
        if cp1.charge/cp2.charge < 0: 
            cp1.v= 0
            cp2.v= 0
            cp1.charge= 0
            cp2.charge= 0
            print("Merge")
            
            break
            
        elif cp1.charge/cp2.charge > 0: 
            cp1.vx = cp1.vx*(-1*(cp1.charge+cp2.charge)*(cp1.m/cp2.m))
            cp2.vx = cp2.vx*(-1*(cp1.charge+cp2.charge)*(cp2.m/cp1.m))
            
            cp1.vy = cp1.vy*(-1*(cp1.charge+cp2.charge)*(cp1.m/cp2.m))
            cp2.vy = cp2.vy*(-1*(cp1.charge+cp2.charge)*(cp2.m/cp1.m))
            
            cp1.vz = cp1.vz*(-1*(cp1.charge+cp2.charge)*(cp1.m/cp2.m))
            cp2.vz = cp2.vz*(-1*(cp1.charge+cp2.charge)*(cp2.m/cp1.m))
            
            print("Repel- Charges have the same sign")
    
    print("c1 position:", cp1.rx, cp1.ry, cp1.rz, cp1.vx, cp1.vy, cp1.vz)
    print("c2 position:", cp2.rx, cp2.ry, cp2.rz, cp2.vx, cp2.vy, cp2.vz)
# Out:
# c1 position: -4.9 -4.9 -4.9 2 2 2
# c2 position: 4.95 4.95 4.95 -1 -1 -1
# c1 position: -4.800000000000001 -4.800000000000001 -4.800000000000001 2 2 2
# c2 position: 4.9 4.9 4.9 -1 -1 -1
# c1 position: -4.700000000000001 -4.700000000000001 -4.700000000000001 2 2 2
# c2 position: 4.8500000000000005 4.8500000000000005 4.8500000000000005 -1 -1 -1
# c1 position: -4.600000000000001 -4.600000000000001 -4.600000000000001 2 2 2
# c2 position: 4.800000000000001 4.800000000000001 4.800000000000001 -1 -1 -1
# c1 position: -4.500000000000002 -4.500000000000002 -4.500000000000002 2 2 2
# c2 position: 4.750000000000001 4.750000000000001 4.750000000000001 -1 -1 -1
# c1 position: -4.400000000000002 -4.400000000000002 -4.400000000000002 2 2 2
# c2 position: 4.700000000000001 4.700000000000001 4.700000000000001 -1 -1 -1
# c1 position: -4.3000000000000025 -4.3000000000000025 -4.3000000000000025 2 2 2
# c2 position: 4.650000000000001 4.650000000000001 4.650000000000001 -1 -1 -1
# ...

# %% [markdown]
# # Remining Assignments and Due Dates!
# ### Quiz #4 - TODAY
# ### HW 11 - Due Friday 11/22, 5pm (this assignemnt)
# ### HW 12 - Due Monday 12/2, 5pm (next week, Data fitting)
# ### HW 13 - Due Wednesday 12/4, 11:59pm (after Thanksgiving, LaTeX)
# ### Project - Due Monday 12/9, 11am (Code and LaTeX report)
# ### Quiz #5 ("Final") - Monday 12/9, 11am (written)
